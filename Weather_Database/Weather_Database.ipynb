# %% [markdown]
# ## Module 6 Challenge

# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import citipy
from citipy import citipy

#Import requests library
import requests
from config2 import API_key
import json

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create a set of random lattitude and longitude  combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?&appid=" + API_key
city_url = url + "&q=" + "London"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&appid=c6ee939be8c685eec6363c5292baf5da&q=London

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 282.54,
#   'feels_like': 279.25,
#   'temp_min': 281.31,
#   'temp_max': 283.29,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 7.2, 'deg': 240},
#  'clouds': {'all': 40},
#  'dt': 1644083586,
#  'sys': {'type': 2,
#   'id': 2019646,
#   'country': 'GB',
#   'sunrise': 1644046365,
#   'sunset': 1644080174},
#  'timezone': 0,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
city_weather["weather"][0]["description"]
# Out:
# 'light snow'

# %%
city_data = []
record_count = 0 
set_count=0

print("Beginning Data Retrieval     ")
print("-----------------------------")

for i,city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try: 
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind, 
                         "Country": city_country,
                         "Date": city_date,
                         "Current Description": city_description})
        
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate that data loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 0 of Set 0 | souillac
# Processing record 1 of Set 0 | flinders
# Processing record 2 of Set 0 | provideniya
# Processing record 3 of Set 0 | cape town
# Processing record 4 of Set 0 | saint-pierre
# Processing record 5 of Set 0 | ushuaia
# Processing record 6 of Set 0 | mataura
# Processing record 7 of Set 0 | narsaq
# Processing record 8 of Set 0 | busselton
# Processing record 9 of Set 0 | faanui
# Processing record 10 of Set 0 | grindavik
# Processing record 11 of Set 0 | vila velha
# Processing record 12 of Set 0 | balao
# Processing record 13 of Set 0 | lorengau
# Processing record 14 of Set 0 | maningrida
# Processing record 15 of Set 0 | arraial do cabo
# Processing record 16 of Set 0 | bembibre
# Processing record 17 of Set 0 | tuktoyaktuk
# Processing record 18 of Set 0 | sitka
# Processing record 19 of Set 0 | san francisco
# Processing record 20 of Set 0 | punta arenas
# Processing record 21 of Set 0 | taolanaro
# City not found. Skipping...
# Processing record 22 of Set 0 | avera
# Processing record 23 of Set 0 | butaritari
# Processing record 24 of Set 0 | port hedland
# Processing record 25 of Set 0 | castro
# Processing record 26 of Set 0 | westport
# Processing record 27 of Set 0 | rawannawi
# City not found. Skipping...
# Processing record 28 of Set 0 | hirara
# Processing record 29 of Set 0 | albany
# Processing record 30 of Set 0 | mar del plata
# Processing record 31 of Set 0 | sandovo
# Processing record 32 of Set 0 | necochea
# Processing record 33 of Set 0 | hithadhoo
# Processing record 34 of Set 0 | mahebourg
# Processing record 35 of Set 0 | udachnyy
# Processing record 36 of Set 0 | buala
# Processing record 37 of Set 0 | biltine
# Processing record 38 of Set 0 | carnarvon
# Processing record 39 of Set 0 | kieta
# Processing record 40 of Set 0 | barrow
# Processing record 41 of Set 0 | kaitangata
# Processing record 42 of Set 0 | hobart
# Processing record 43 of Set 0 | tahara
# Processing record 44 of Set 0 | avarua
# Processing record 45 of Set 0 | atuona
# Processing record 46 of Set 0 | bayangol
# Processing record 47 of Set 0 | dalvik
# Processing record 48 of Set 0 | manaus
# Processing record 49 of Set 0 | lasa
# Processing record 1 of Set 1 | nagato
# Processing record 2 of Set 1 | dikson
# Processing record 3 of Set 1 | khatanga
# Processing record 4 of Set 1 | vaini
# Processing record 5 of Set 1 | isangel
# Processing record 6 of Set 1 | sarakhs
# Processing record 7 of Set 1 | thompson
# Processing record 8 of Set 1 | tiksi
# Processing record 9 of Set 1 | lebu
# Processing record 10 of Set 1 | labutta
# City not found. Skipping...
# Processing record 11 of Set 1 | drugovo
# Processing record 12 of Set 1 | rikitea
# Processing record 13 of Set 1 | hambantota
# Processing record 14 of Set 1 | codrington
# Processing record 15 of Set 1 | dingle
# Processing record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing record 17 of Set 1 | touros
# Processing record 18 of Set 1 | harwich
# Processing record 19 of Set 1 | hilo
# Processing record 20 of Set 1 | constitucion
# Processing record 21 of Set 1 | shelburne
# Processing record 22 of Set 1 | sinkat
# City not found. Skipping...
# Processing record 23 of Set 1 | key west
# Processing record 24 of Set 1 | cap malheureux
# Processing record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing record 26 of Set 1 | fortuna
# Processing record 27 of Set 1 | qaanaaq
# Processing record 28 of Set 1 | neuquen
# Processing record 29 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing record 30 of Set 1 | saint-georges
# Processing record 31 of Set 1 | sistranda
# Processing record 32 of Set 1 | saskylakh
# Processing record 33 of Set 1 | cherskiy
# Processing record 34 of Set 1 | ostrovnoy
# Processing record 35 of Set 1 | nanortalik
# Processing record 36 of Set 1 | katsuura
# Processing record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing record 40 of Set 1 | gary
# Processing record 41 of Set 1 | ponta do sol
# Processing record 42 of Set 1 | zachagansk
# City not found. Skipping...
# Processing record 43 of Set 1 | kirensk
# Processing record 44 of Set 1 | chuy
# Processing record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing record 46 of Set 1 | puerto ayora
# Processing record 47 of Set 1 | upernavik
# Processing record 48 of Set 1 | alugan
# Processing record 49 of Set 1 | hermanus
# Processing record 50 of Set 1 | port elizabeth
# Processing record 1 of Set 2 | luderitz
# Processing record 2 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing record 3 of Set 2 | kapaa
# Processing record 4 of Set 2 | lokoja
# Processing record 5 of Set 2 | uruzgan
# Processing record 6 of Set 2 | esperance
# Processing record 7 of Set 2 | clyde river
# Processing record 8 of Set 2 | torbay
# Processing record 9 of Set 2 | san patricio
# Processing record 10 of Set 2 | chokurdakh
# Processing record 11 of Set 2 | port alfred
# Processing record 12 of Set 2 | yatou
# Processing record 13 of Set 2 | oranjemund
# Processing record 14 of Set 2 | sao joao da barra
# Processing record 15 of Set 2 | merauke
# Processing record 16 of Set 2 | vardo
# Processing record 17 of Set 2 | lompoc
# Processing record 18 of Set 2 | kot samaba
# Processing record 19 of Set 2 | boundiali
# Processing record 20 of Set 2 | kruisfontein
# Processing record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing record 22 of Set 2 | kulhudhuffushi
# Processing record 23 of Set 2 | wahiawa
# Processing record 24 of Set 2 | mwense
# Processing record 25 of Set 2 | bridlington
# Processing record 26 of Set 2 | bilibino
# Processing record 27 of Set 2 | dzilam gonzalez
# Processing record 28 of Set 2 | ambon
# Processing record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing record 30 of Set 2 | ossora
# Processing record 31 of Set 2 | skibbereen
# Processing record 32 of Set 2 | genhe
# Processing record 33 of Set 2 | bayreuth
# Processing record 34 of Set 2 | ocumare del tuy
# Processing record 35 of Set 2 | grand river south east
# City not found. Skipping...
# Processing record 36 of Set 2 | talnakh
# Processing record 37 of Set 2 | kiknur
# Processing record 38 of Set 2 | mubende
# Processing record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing record 40 of Set 2 | stolin
# Processing record 41 of Set 2 | boulder
# Processing record 42 of Set 2 | soderhamn
# Processing record 43 of Set 2 | abalak
# Processing record 44 of Set 2 | alofi
# Processing record 45 of Set 2 | susanville
# Processing record 46 of Set 2 | ancud
# Processing record 47 of Set 2 | liku
# Processing record 48 of Set 2 | nikolskoye
# Processing record 49 of Set 2 | saldanha
# Processing record 50 of Set 2 | ipueiras
# Processing record 1 of Set 3 | namibe
# Processing record 2 of Set 3 | longhua
# Processing record 3 of Set 3 | teguise
# Processing record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing record 5 of Set 3 | norman wells
# Processing record 6 of Set 3 | kuche
# City not found. Skipping...
# Processing record 7 of Set 3 | gamba
# Processing record 8 of Set 3 | sola
# Processing record 9 of Set 3 | new norfolk
# Processing record 10 of Set 3 | batagay-alyta
# Processing record 11 of Set 3 | jamestown
# Processing record 12 of Set 3 | tasiilaq
# Processing record 13 of Set 3 | bambous virieux
# Processing record 14 of Set 3 | ulkan
# Processing record 15 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing record 16 of Set 3 | chom bung
# City not found. Skipping...
# Processing record 17 of Set 3 | khutar
# Processing record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing record 19 of Set 3 | guerrero negro
# Processing record 20 of Set 3 | japura
# Processing record 21 of Set 3 | airai
# Processing record 22 of Set 3 | phan rang
# City not found. Skipping...
# Processing record 23 of Set 3 | husavik
# Processing record 24 of Set 3 | zheshart
# Processing record 25 of Set 3 | ruatoria
# City not found. Skipping...
# Processing record 26 of Set 3 | tala
# Processing record 27 of Set 3 | stornoway
# Processing record 28 of Set 3 | faya
# Processing record 29 of Set 3 | bredasdorp
# Processing record 30 of Set 3 | iqaluit
# Processing record 31 of Set 3 | yzeure
# Processing record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing record 33 of Set 3 | sabang
# Processing record 34 of Set 3 | san ramon
# Processing record 35 of Set 3 | anchorage
# Processing record 36 of Set 3 | ouadda
# Processing record 37 of Set 3 | yellowknife
# Processing record 38 of Set 3 | santa cruz
# Processing record 39 of Set 3 | jalu
# Processing record 40 of Set 3 | tiznit
# Processing record 41 of Set 3 | bluff
# Processing record 42 of Set 3 | cabedelo
# Processing record 43 of Set 3 | opuwo
# Processing record 44 of Set 3 | conde
# Processing record 45 of Set 3 | sao filipe
# Processing record 46 of Set 3 | saint-philippe
# Processing record 47 of Set 3 | bakchar
# Processing record 48 of Set 3 | kargopol
# Processing record 49 of Set 3 | klaksvik
# Processing record 50 of Set 3 | sioux lookout
# Processing record 1 of Set 4 | rungata
# City not found. Skipping...
# Processing record 2 of Set 4 | kourou
# Processing record 3 of Set 4 | sassandra
# Processing record 4 of Set 4 | ribeira grande
# Processing record 5 of Set 4 | sorgun
# Processing record 6 of Set 4 | uarini
# Processing record 7 of Set 4 | teya
# Processing record 8 of Set 4 | tuatapere
# Processing record 9 of Set 4 | baiyin
# Processing record 10 of Set 4 | mabaruma
# Processing record 11 of Set 4 | cumana
# Processing record 12 of Set 4 | bokoro
# Processing record 13 of Set 4 | pevek
# Processing record 14 of Set 4 | placido de castro
# Processing record 15 of Set 4 | vanimo
# Processing record 16 of Set 4 | snezhnogorsk
# Processing record 17 of Set 4 | waw
# Processing record 18 of Set 4 | palmer
# Processing record 19 of Set 4 | chazuta
# Processing record 20 of Set 4 | fort frances
# Processing record 21 of Set 4 | puerto penasco
# Processing record 22 of Set 4 | georgetown
# Processing record 23 of Set 4 | santa helena de goias
# Processing record 24 of Set 4 | inirida
# Processing record 25 of Set 4 | matagami
# Processing record 26 of Set 4 | arnold
# Processing record 27 of Set 4 | priiskovyy
# Processing record 28 of Set 4 | jabiru
# City not found. Skipping...
# Processing record 29 of Set 4 | tadine
# Processing record 30 of Set 4 | bilma
# Processing record 31 of Set 4 | navalmoral de la mata
# Processing record 32 of Set 4 | la ronge
# Processing record 33 of Set 4 | yerbogachen
# Processing record 34 of Set 4 | lodja
# Processing record 35 of Set 4 | oussouye
# Processing record 36 of Set 4 | naze
# Processing record 37 of Set 4 | longyearbyen
# Processing record 38 of Set 4 | macklin
# Processing record 39 of Set 4 | belmonte
# Processing record 40 of Set 4 | umm jarr
# City not found. Skipping...
# Processing record 41 of Set 4 | wanaka
# Processing record 42 of Set 4 | agadir
# Processing record 43 of Set 4 | geraldton
# Processing record 44 of Set 4 | belle fourche
# Processing record 45 of Set 4 | cabo san lucas
# Processing record 46 of Set 4 | bonavista
# Processing record 47 of Set 4 | nemencine
# Processing record 48 of Set 4 | adrar
# Processing record 49 of Set 4 | lazaro cardenas
# Processing record 50 of Set 4 | komsomolskiy
# Processing record 1 of Set 5 | xinqing
# Processing record 2 of Set 5 | aklavik
# Processing record 3 of Set 5 | daru
# Processing record 4 of Set 5 | mandalgovi
# Processing record 5 of Set 5 | severo-kurilsk
# Processing record 6 of Set 5 | sisimiut
# Processing record 7 of Set 5 | honiara
# Processing record 8 of Set 5 | matay
# Processing record 9 of Set 5 | asfi
# Processing record 10 of Set 5 | jinsha
# Processing record 11 of Set 5 | campo gobierno
# Processing record 12 of Set 5 | fairbanks
# Processing record 13 of Set 5 | tura
# Processing record 14 of Set 5 | asau
# Processing record 15 of Set 5 | batemans bay
# Processing record 16 of Set 5 | nuuk
# Processing record 17 of Set 5 | kahului
# Processing record 18 of Set 5 | bethel
# Processing record 19 of Set 5 | niksar
# Processing record 20 of Set 5 | trincomalee
# Processing record 21 of Set 5 | pierre
# Processing record 22 of Set 5 | muravlenko
# Processing record 23 of Set 5 | rawson
# Processing record 24 of Set 5 | mayumba
# Processing record 25 of Set 5 | ust-tsilma
# Processing record 26 of Set 5 | tubruq
# City not found. Skipping...
# Processing record 27 of Set 5 | colon
# Processing record 28 of Set 5 | toamasina
# Processing record 29 of Set 5 | kawhia
# Processing record 30 of Set 5 | tucuman
# Processing record 31 of Set 5 | ahipara
# Processing record 32 of Set 5 | curup
# Processing record 33 of Set 5 | victoria
# Processing record 34 of Set 5 | atar
# Processing record 35 of Set 5 | ilulissat
# Processing record 36 of Set 5 | menongue
# Processing record 37 of Set 5 | kodiak
# Processing record 38 of Set 5 | meulaboh
# Processing record 39 of Set 5 | qui nhon
# Processing record 40 of Set 5 | bathsheba
# Processing record 41 of Set 5 | puerto leguizamo
# Processing record 42 of Set 5 | toulepleu
# City not found. Skipping...
# Processing record 43 of Set 5 | pemangkat
# Processing record 44 of Set 5 | hami
# Processing record 45 of Set 5 | fort nelson
# Processing record 46 of Set 5 | freeport
# Processing record 47 of Set 5 | salalah
# Processing record 48 of Set 5 | warri
# Processing record 49 of Set 5 | saint george
# Processing record 50 of Set 5 | nizwa
# Processing record 1 of Set 6 | mayor pablo lagerenza
# Processing record 2 of Set 6 | la libertad
# Processing record 3 of Set 6 | aviles
# Processing record 4 of Set 6 | totness
# Processing record 5 of Set 6 | povenets
# Processing record 6 of Set 6 | rieti
# Processing record 7 of Set 6 | malinao
# Processing record 8 of Set 6 | sambava
# Processing record 9 of Set 6 | abdanan
# Processing record 10 of Set 6 | sorvag
# City not found. Skipping...
# Processing record 11 of Set 6 | laguna
# Processing record 12 of Set 6 | santa rosa
# Processing record 13 of Set 6 | muros
# Processing record 14 of Set 6 | margate
# Processing record 15 of Set 6 | cacequi
# Processing record 16 of Set 6 | knin
# Processing record 17 of Set 6 | seminole
# Processing record 18 of Set 6 | vysokogornyy
# Processing record 19 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing record 20 of Set 6 | anloga
# Processing record 21 of Set 6 | gangotri
# City not found. Skipping...
# Processing record 22 of Set 6 | straldza
# City not found. Skipping...
# Processing record 23 of Set 6 | tete
# Processing record 24 of Set 6 | sao mateus
# Processing record 25 of Set 6 | toliary
# City not found. Skipping...
# Processing record 26 of Set 6 | lagoa
# Processing record 27 of Set 6 | hervey bay
# Processing record 28 of Set 6 | primero de enero
# Processing record 29 of Set 6 | quesnel
# Processing record 30 of Set 6 | lata
# Processing record 31 of Set 6 | raymondville
# Processing record 32 of Set 6 | tabiauea
# City not found. Skipping...
# Processing record 33 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing record 34 of Set 6 | wilmington
# Processing record 35 of Set 6 | ewa beach
# Processing record 36 of Set 6 | yilan
# Processing record 37 of Set 6 | tawkar
# City not found. Skipping...
# Processing record 38 of Set 6 | port-cartier
# Processing record 39 of Set 6 | lushunkou
# City not found. Skipping...
# Processing record 40 of Set 6 | tucurui
# Processing record 41 of Set 6 | caraballeda
# Processing record 42 of Set 6 | ulladulla
# Processing record 43 of Set 6 | shimoda
# Processing record 44 of Set 6 | mana
# Processing record 45 of Set 6 | padang
# Processing record 46 of Set 6 | ginda
# Processing record 47 of Set 6 | juegang
# Processing record 48 of Set 6 | hueytown
# Processing record 49 of Set 6 | san andres
# Processing record 50 of Set 6 | kavaratti
# Processing record 1 of Set 7 | sabha
# Processing record 2 of Set 7 | mayari
# City not found. Skipping...
# Processing record 3 of Set 7 | fort william
# Processing record 4 of Set 7 | havre-saint-pierre
# Processing record 5 of Set 7 | coquimbo
# Processing record 6 of Set 7 | praia
# Processing record 7 of Set 7 | saleaula
# City not found. Skipping...
# Processing record 8 of Set 7 | east london
# Processing record 9 of Set 7 | las juntas
# Processing record 10 of Set 7 | bubaque
# Processing record 11 of Set 7 | cayenne
# Processing record 12 of Set 7 | burewala
# Processing record 13 of Set 7 | baragua
# Processing record 14 of Set 7 | poum
# Processing record 15 of Set 7 | kavieng
# Processing record 16 of Set 7 | haverfordwest
# Processing record 17 of Set 7 | ashland
# Processing record 18 of Set 7 | tupancireta
# Processing record 19 of Set 7 | khasan
# Processing record 20 of Set 7 | kualakapuas
# Processing record 21 of Set 7 | wuwei
# Processing record 22 of Set 7 | wahran
# City not found. Skipping...
# Processing record 23 of Set 7 | bria
# Processing record 24 of Set 7 | viedma
# Processing record 25 of Set 7 | olafsvik
# Processing record 26 of Set 7 | poronaysk
# Processing record 27 of Set 7 | san cristobal
# Processing record 28 of Set 7 | baghdad
# Processing record 29 of Set 7 | mandera
# Processing record 30 of Set 7 | newport
# Processing record 31 of Set 7 | chikoy
# City not found. Skipping...
# Processing record 32 of Set 7 | nelson bay
# Processing record 33 of Set 7 | cidreira
# Processing record 34 of Set 7 | dwarka
# Processing record 35 of Set 7 | maceio
# Processing record 36 of Set 7 | platanos
# Processing record 37 of Set 7 | gore
# Processing record 38 of Set 7 | kalat
# Processing record 39 of Set 7 | kutum
# Processing record 40 of Set 7 | karaul
# City not found. Skipping...
# Processing record 41 of Set 7 | qarqin
# Processing record 42 of Set 7 | grand-santi
# Processing record 43 of Set 7 | port lincoln
# Processing record 44 of Set 7 | tautira
# Processing record 45 of Set 7 | saint-augustin
# Processing record 46 of Set 7 | sucua
# Processing record 47 of Set 7 | xiaoshan
# Processing record 48 of Set 7 | vila franca do campo
# Processing record 49 of Set 7 | whyalla
# Processing record 50 of Set 7 | chara
# Processing record 1 of Set 8 | knysna
# Processing record 2 of Set 8 | panacan
# Processing record 3 of Set 8 | portobelo
# Processing record 4 of Set 8 | saint anthony
# Processing record 5 of Set 8 | uige
# Processing record 6 of Set 8 | graham
# Processing record 7 of Set 8 | exeter
# Processing record 8 of Set 8 | beyneu
# Processing record 9 of Set 8 | monroe
# Processing record 10 of Set 8 | aykhal
# Processing record 11 of Set 8 | isla mujeres
# Processing record 12 of Set 8 | svetlaya
# Processing record 13 of Set 8 | kariba
# Processing record 14 of Set 8 | listvyagi
# Processing record 15 of Set 8 | itaituba
# Processing record 16 of Set 8 | alice springs
# Processing record 17 of Set 8 | la rioja
# Processing record 18 of Set 8 | moerai
# Processing record 19 of Set 8 | kota bahru
# Processing record 20 of Set 8 | vao
# Processing record 21 of Set 8 | bacolod
# Processing record 22 of Set 8 | tabuleiro do norte
# Processing record 23 of Set 8 | camacha
# Processing record 24 of Set 8 | aswan
# Processing record 25 of Set 8 | sovetskiy
# Processing record 26 of Set 8 | autazes
# Processing record 27 of Set 8 | kirovsk
# Processing record 28 of Set 8 | puerto rico
# Processing record 29 of Set 8 | yar-sale
# Processing record 30 of Set 8 | mahibadhoo
# Processing record 31 of Set 8 | oistins
# Processing record 32 of Set 8 | polson
# Processing record 33 of Set 8 | kinkala
# Processing record 34 of Set 8 | lufilufi
# Processing record 35 of Set 8 | mount isa
# Processing record 36 of Set 8 | phan thiet
# Processing record 37 of Set 8 | jiaonan
# Processing record 38 of Set 8 | marfino
# Processing record 39 of Set 8 | yurga
# Processing record 40 of Set 8 | port-gentil
# Processing record 41 of Set 8 | labytnangi
# Processing record 42 of Set 8 | hofn
# Processing record 43 of Set 8 | jiuquan
# Processing record 44 of Set 8 | ndioum
# Processing record 45 of Set 8 | gogrial
# Processing record 46 of Set 8 | tuy hoa
# Processing record 47 of Set 8 | bengkulu
# Processing record 48 of Set 8 | araouane
# Processing record 49 of Set 8 | soyo
# Processing record 50 of Set 8 | caohai
# Processing record 1 of Set 9 | kailua
# Processing record 2 of Set 9 | guilin
# Processing record 3 of Set 9 | northam
# Processing record 4 of Set 9 | saint-francois
# Processing record 5 of Set 9 | wanning
# Processing record 6 of Set 9 | tevaitoa
# Processing record 7 of Set 9 | moses lake
# Processing record 8 of Set 9 | ust-omchug
# Processing record 9 of Set 9 | huntsville
# Processing record 10 of Set 9 | monaragala
# Processing record 11 of Set 9 | kenora
# Processing record 12 of Set 9 | yulara
# Processing record 13 of Set 9 | yumbe
# Processing record 14 of Set 9 | caravelas
# Processing record 15 of Set 9 | shingu
# Processing record 16 of Set 9 | talas
# Processing record 17 of Set 9 | basmat
# Processing record 18 of Set 9 | quelimane
# Processing record 19 of Set 9 | mandurah
# Processing record 20 of Set 9 | poltava
# Processing record 21 of Set 9 | lavrentiya
# Processing record 22 of Set 9 | beringovskiy
# Processing record 23 of Set 9 | razlog
# Processing record 24 of Set 9 | antalaha
# Processing record 25 of Set 9 | okha
# Processing record 26 of Set 9 | tamworth
# Processing record 27 of Set 9 | betioky
# Processing record 28 of Set 9 | hihifo
# City not found. Skipping...
# Processing record 29 of Set 9 | lakhdenpokhya
# Processing record 30 of Set 9 | suntar
# Processing record 31 of Set 9 | black diamond
# Processing record 32 of Set 9 | beidao
# Processing record 33 of Set 9 | ternate
# Processing record 34 of Set 9 | bon air
# Processing record 35 of Set 9 | marienburg
# Processing record 36 of Set 9 | kharan
# Processing record 37 of Set 9 | llandrindod wells
# Processing record 38 of Set 9 | senno
# Processing record 39 of Set 9 | baykit
# Processing record 40 of Set 9 | mwinilunga
# Processing record 41 of Set 9 | blackfalds
# Processing record 42 of Set 9 | shizunai
# Processing record 43 of Set 9 | sorland
# Processing record 44 of Set 9 | barahona
# Processing record 45 of Set 9 | moree
# Processing record 46 of Set 9 | san joaquin
# Processing record 47 of Set 9 | nishihara
# Processing record 48 of Set 9 | guarapari
# Processing record 49 of Set 9 | saint-joseph
# Processing record 50 of Set 9 | leningradskiy
# Processing record 1 of Set 10 | mapastepec
# Processing record 2 of Set 10 | istmina
# Processing record 3 of Set 10 | berlevag
# Processing record 4 of Set 10 | tommot
# Processing record 5 of Set 10 | novikovo
# Processing record 6 of Set 10 | camana
# Processing record 7 of Set 10 | broken hill
# Processing record 8 of Set 10 | carballo
# Processing record 9 of Set 10 | erzin
# Processing record 10 of Set 10 | los andes
# Processing record 11 of Set 10 | arlit
# Processing record 12 of Set 10 | srednekolymsk
# Processing record 13 of Set 10 | santa ana
# Processing record 14 of Set 10 | george town
# Processing record 15 of Set 10 | pisco
# Processing record 16 of Set 10 | ferme-neuve
# Processing record 17 of Set 10 | mangai
# Processing record 18 of Set 10 | high rock
# Processing record 19 of Set 10 | shaoyang
# Processing record 20 of Set 10 | batticaloa
# Processing record 21 of Set 10 | nanakuli
# Processing record 22 of Set 10 | gushikawa
# Processing record 23 of Set 10 | pangnirtung
# Processing record 24 of Set 10 | landsberg
# Processing record 25 of Set 10 | sundsvall
# Processing record 26 of Set 10 | toropets
# Processing record 27 of Set 10 | andevoranto
# City not found. Skipping...
# Processing record 28 of Set 10 | ugoofaaru
# Processing record 29 of Set 10 | bonthe
# Processing record 30 of Set 10 | nouadhibou
# Processing record 31 of Set 10 | jijiga
# Processing record 32 of Set 10 | puerto madryn
# Processing record 33 of Set 10 | haines junction
# Processing record 34 of Set 10 | hasaki
# Processing record 35 of Set 10 | razole
# Processing record 36 of Set 10 | hamilton
# Processing record 37 of Set 10 | denia
# Processing record 38 of Set 10 | teknaf
# Processing record 39 of Set 10 | barranca
# Processing record 40 of Set 10 | yangambi
# Processing record 41 of Set 10 | durban
# Processing record 42 of Set 10 | kresttsy
# Processing record 43 of Set 10 | parati
# Processing record 44 of Set 10 | broome
# Processing record 45 of Set 10 | karpathos
# Processing record 46 of Set 10 | nome
# Processing record 47 of Set 10 | guaruja
# Processing record 48 of Set 10 | along
# Processing record 49 of Set 10 | hualmay
# Processing record 50 of Set 10 | svetlogorsk
# Processing record 1 of Set 11 | san jeronimo
# Processing record 2 of Set 11 | safaga
# Processing record 3 of Set 11 | nguiu
# City not found. Skipping...
# Processing record 4 of Set 11 | sampit
# Processing record 5 of Set 11 | tchollire
# Processing record 6 of Set 11 | male
# Processing record 7 of Set 11 | leh
# Processing record 8 of Set 11 | inhambane
# Processing record 9 of Set 11 | road town
# Processing record 10 of Set 11 | zhongshu
# Processing record 11 of Set 11 | pacific grove
# Processing record 12 of Set 11 | riyadh
# Processing record 13 of Set 11 | launceston
# Processing record 14 of Set 11 | kirakira
# Processing record 15 of Set 11 | nehe
# Processing record 16 of Set 11 | buchanan
# Processing record 17 of Set 11 | puerto narino
# Processing record 18 of Set 11 | moberly
# Processing record 19 of Set 11 | ramos arizpe
# Processing record 20 of Set 11 | sturgeon bay
# Processing record 21 of Set 11 | satitoa
# City not found. Skipping...
# Processing record 22 of Set 11 | marawi
# Processing record 23 of Set 11 | okhotsk
# Processing record 24 of Set 11 | egvekinot
# Processing record 25 of Set 11 | verkhnyaya inta
# Processing record 26 of Set 11 | halalo
# City not found. Skipping...
# Processing record 27 of Set 11 | coihaique
# Processing record 28 of Set 11 | bracebridge
# Processing record 29 of Set 11 | zlobin
# Processing record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing record 31 of Set 11 | volary
# Processing record 32 of Set 11 | bako
# Processing record 33 of Set 11 | araguatins
# City not found. Skipping...
# Processing record 34 of Set 11 | porto novo
# Processing record 35 of Set 11 | zyryanka
# Processing record 36 of Set 11 | sao miguel do araguaia
# Processing record 37 of Set 11 | albion
# Processing record 38 of Set 11 | moron
# Processing record 39 of Set 11 | porosozero
# Processing record 40 of Set 11 | maniitsoq
# Processing record 41 of Set 11 | arman
# Processing record 42 of Set 11 | mitchell
# Processing record 43 of Set 11 | gigmoto
# Processing record 44 of Set 11 | ozuluama
# Processing record 45 of Set 11 | gambela
# Processing record 46 of Set 11 | sawakin
# Processing record 47 of Set 11 | bharatpur
# Processing record 48 of Set 11 | labuhan
# Processing record 49 of Set 11 | svobodnyy
# Processing record 50 of Set 11 | gorontalo
# Processing record 1 of Set 12 | omboue
# Processing record 2 of Set 12 | solenzo
# Processing record 3 of Set 12 | artyk
# City not found. Skipping...
# Processing record 4 of Set 12 | xichang
# Processing record 5 of Set 12 | winona
# Processing record 6 of Set 12 | salinas
# Processing record 7 of Set 12 | bagar
# Processing record 8 of Set 12 | paamiut
# Processing record 9 of Set 12 | general roca
# Processing record 10 of Set 12 | lalibela
# Processing record 11 of Set 12 | thinadhoo
# Processing record 12 of Set 12 | monte alegre
# Processing record 13 of Set 12 | lindi
# Processing record 14 of Set 12 | sorsk
# Processing record 15 of Set 12 | san francisco de cones
# Processing record 16 of Set 12 | hunterville
# Processing record 17 of Set 12 | freetown
# Processing record 18 of Set 12 | port macquarie
# Processing record 19 of Set 12 | wynyard
# Processing record 20 of Set 12 | palana
# Processing record 21 of Set 12 | elmadag
# Processing record 22 of Set 12 | kamen-na-obi
# Processing record 23 of Set 12 | melhus
# Processing record 24 of Set 12 | mitsamiouli
# Processing record 25 of Set 12 | malumfashi
# Processing record 26 of Set 12 | eldikan
# City not found. Skipping...
# Processing record 27 of Set 12 | bose
# Processing record 28 of Set 12 | berezovyy
# Processing record 29 of Set 12 | merrill
# Processing record 30 of Set 12 | clarksburg
# Processing record 31 of Set 12 | umm kaddadah
# Processing record 32 of Set 12 | kefamenanu
# Processing record 33 of Set 12 | kudus
# Processing record 34 of Set 12 | nalut
# Processing record 35 of Set 12 | espinosa
# Processing record 36 of Set 12 | central point
# Processing record 37 of Set 12 | port hardy
# Processing record 38 of Set 12 | sao geraldo do araguaia
# Processing record 39 of Set 12 | palauig
# Processing record 40 of Set 12 | ngukurr
# City not found. Skipping...
# Processing record 41 of Set 12 | port blair
# Processing record 42 of Set 12 | acapulco
# Processing record 43 of Set 12 | cowra
# Processing record 44 of Set 12 | fot
# Processing record 45 of Set 12 | gouyave
# Processing record 46 of Set 12 | ngunguru
# Processing record 47 of Set 12 | richards bay
# Processing record 48 of Set 12 | gat
# Processing record 49 of Set 12 | eyl
# Processing record 50 of Set 12 | college
# Processing record 1 of Set 13 | hokitika
# Processing record 2 of Set 13 | onalaska
# Processing record 3 of Set 13 | hay river
# Processing record 4 of Set 13 | chapais
# Processing record 5 of Set 13 | amga
# Processing record 6 of Set 13 | makakilo city
# Processing record 7 of Set 13 | leninskoye
# Processing record 8 of Set 13 | ouesso
# Processing record 9 of Set 13 | koumac
# Processing record 10 of Set 13 | adre
# Processing record 11 of Set 13 | awbari
# Processing record 12 of Set 13 | raudeberg
# Processing record 13 of Set 13 | solnechnyy
# Processing record 14 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing record 15 of Set 13 | balykshi
# Processing record 16 of Set 13 | emerald
# Processing record 17 of Set 13 | antofagasta
# Processing record 18 of Set 13 | wakkanai
# Processing record 19 of Set 13 | ratnagiri
# Processing record 20 of Set 13 | talcahuano
# Processing record 21 of Set 13 | sherpur
# Processing record 22 of Set 13 | pankrushikha
# Processing record 23 of Set 13 | gravdal
# Processing record 24 of Set 13 | kargat
# Processing record 25 of Set 13 | quatre cocos
# Processing record 26 of Set 13 | dubbo
# Processing record 27 of Set 13 | san jose
# Processing record 28 of Set 13 | stepnogorsk
# Processing record 29 of Set 13 | konevo
# Processing record 30 of Set 13 | vanavara
# Processing record 31 of Set 13 | los llanos de aridane
# Processing record 32 of Set 13 | tanete
# Processing record 33 of Set 13 | atchison
# Processing record 34 of Set 13 | bar-le-duc
# Processing record 35 of Set 13 | libreville
# Processing record 36 of Set 13 | kostomuksha
# Processing record 37 of Set 13 | dharchula
# Processing record 38 of Set 13 | nioro
# Processing record 39 of Set 13 | the valley
# Processing record 40 of Set 13 | vychegodskiy
# Processing record 41 of Set 13 | kapit
# Processing record 42 of Set 13 | chiredzi
# Processing record 43 of Set 13 | high level
# Processing record 44 of Set 13 | bunia
# Processing record 45 of Set 13 | pokhara
# Processing record 46 of Set 13 | tabou
# Processing record 47 of Set 13 | gallup
# Processing record 48 of Set 13 | bitung
# Processing record 49 of Set 13 | chifeng
# Processing record 50 of Set 13 | ha giang
# Processing record 1 of Set 14 | berdigestyakh
# Processing record 2 of Set 14 | sibolga
# Processing record 3 of Set 14 | sibu
# Processing record 4 of Set 14 | kipushi
# Processing record 5 of Set 14 | kuala terengganu
# Processing record 6 of Set 14 | marzuq
# Processing record 7 of Set 14 | marsa matruh
# Processing record 8 of Set 14 | sorata
# Processing record 9 of Set 14 | komatipoort
# Processing record 10 of Set 14 | rio grande
# Processing record 11 of Set 14 | ciamis
# Processing record 12 of Set 14 | umm lajj
# Processing record 13 of Set 14 | pisz
# Processing record 14 of Set 14 | whitehorse
# Processing record 15 of Set 14 | huarmey
# Processing record 16 of Set 14 | petropavlovsk-kamchatskiy
# Processing record 17 of Set 14 | haysville
# Processing record 18 of Set 14 | inzer
# Processing record 19 of Set 14 | salym
# Processing record 20 of Set 14 | vestmanna
# Processing record 21 of Set 14 | obu
# Processing record 22 of Set 14 | pinheiro
# Processing record 23 of Set 14 | dawei
# Processing record 24 of Set 14 | urucara
# Processing record 25 of Set 14 | narasimharajapura
# Processing record 26 of Set 14 | hamina
# Processing record 27 of Set 14 | samarai
# Processing record 28 of Set 14 | zhoucheng
# Processing record 29 of Set 14 | brae
# Processing record 30 of Set 14 | mersing
# Processing record 31 of Set 14 | goma
# Processing record 32 of Set 14 | kismayo
# Processing record 33 of Set 14 | banda aceh
# Processing record 34 of Set 14 | wajima
# Processing record 35 of Set 14 | namatanai
# Processing record 36 of Set 14 | honningsvag
# Processing record 37 of Set 14 | mangrol
# Processing record 38 of Set 14 | poros
# Processing record 39 of Set 14 | kununurra
# Processing record 40 of Set 14 | lincoln
# Processing record 41 of Set 14 | dunedin
# Processing record 42 of Set 14 | sept-iles
# Processing record 43 of Set 14 | deputatskiy
# Processing record 44 of Set 14 | mazatlan
# Processing record 45 of Set 14 | igrim
# Processing record 46 of Set 14 | rundu
# Processing record 47 of Set 14 | kiruna
# Processing record 48 of Set 14 | tanout
# Processing record 49 of Set 14 | sardarpur
# Processing record 50 of Set 14 | jalalpur jattan
# Processing record 1 of Set 15 | vidim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Souillac -20.5167   57.5167    300.02        89          75
# 1      Flinders -34.5833  150.8552    293.36        80          99
# 2   Provideniya  64.3833 -173.3000    252.07        86           2
# 3     Cape Town -33.9258   18.4232    298.64        65           0
# 4  Saint-Pierre -21.3393   55.4781    300.97        69           0
#
#    Wind Speed Country                 Date          Current Description
# 0        9.26      MU  2022-02-05 18:20:27  light intensity shower rain
# 1        3.13      AU  2022-02-05 18:20:27                   light rain
# 2        4.81      RU  2022-02-05 18:20:27                    clear sky
# 3        6.69      ZA  2022-02-05 18:20:27                    clear sky
# 4        4.12      RE  2022-02-05 18:20:27                    clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Souillac      MU -20.5167   57.5167    300.02        89
# 1           Flinders      AU -34.5833  150.8552    293.36        80
# 2        Provideniya      RU  64.3833 -173.3000    252.07        86
# 3          Cape Town      ZA -33.9258   18.4232    298.64        65
# 4       Saint-Pierre      RE -21.3393   55.4781    300.97        69
# ..               ...     ...      ...       ...       ...       ...
# 691           Kiruna      SE  67.8557   20.2251    267.66        93
# 692           Tanout      NE  14.9709    8.8879    291.11        12
# 693        Sardarpur      IN  22.6780   74.9484    289.46        23
# 694  Jalalpur Jattan      PK  32.6374   74.2183    283.08        93
# 695            Vidim      RU  56.4088  103.1106    267.77        95
#
#      Cloudiness  Wind Speed          Current Description
# 0            75        9.26  light intensity shower rain
# 1            99        3.13                   light rain
# 2             2        4.81                    clear sky
# 3             0        6.69                    clear sky
# 4             0        4.12                    clear sky
# ..          ...         ...                          ...
# 691         100        9.77              overcast clouds
# 692           0        5.34                    clear sky
# 693           0        1.75                    clear sky
# 694         100        1.54                         mist
# 695         100        4.65                   light snow
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
