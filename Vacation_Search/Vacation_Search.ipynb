# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df["Max Temp"] = city_data_df["Max Temp"] - 273
city_data_df.head(50)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0         Souillac      MU -20.5167   57.5167     27.02        89
# 1         1         Flinders      AU -34.5833  150.8552     20.36        80
# 2         2      Provideniya      RU  64.3833 -173.3000    -20.93        86
# 3         3        Cape Town      ZA -33.9258   18.4232     25.64        65
# 4         4     Saint-Pierre      RE -21.3393   55.4781     27.97        69
# 5         5          Ushuaia      AR -54.8000  -68.3000     17.96        45
# 6         6          Mataura      NZ -46.1927  168.8643      9.86        90
# 7         7           Narsaq      GL  60.9167  -46.0500    -13.73        73
# 8         8        Busselton      AU -33.6500  115.3333     19.06        76
# 9         9           Faanui      PF -16.4833 -151.7500     27.39        71
# 10       10        Grindavik      IS  63.8424  -22.4338     -2.88        80
# 11       11       Vila Velha      BR -20.3297  -40.2925     29.12        79
# 12       12            Balao      EC  -2.9167  -79.8167     28.10        73
# 13       13         Lorengau      PG  -2.0226  147.2712     27.21        77
# 14       14       Maningrida      AU -12.0667  134.2667     24.58        84
# 15       15  Arraial Do Cabo      BR -22.9661  -42.0278     31.13        70
# 16       16         Bembibre      ES  42.6177   -6.4155      9.18        68
# 17       17      Tuktoyaktuk      CA  69.4541 -133.0374    -35.85        68
# 18       18            Sitka      US  57.0531 -135.3300      6.09        81
# 19       19    San Francisco      US  37.7749 -122.4194     15.23        69
# 20       20     Punta Arenas      CL -53.1500  -70.9167     19.21        52
# 21       21            Avera      US  33.1940  -82.5271     10.53        47
# 22       22       Butaritari      KI   3.0707  172.7902     28.06        70
# 23       23     Port Hedland      AU -20.3167  118.5667     29.18        79
# 24       24           Castro      BR -24.7911  -50.0119     24.51        78
# 25       25         Westport      US  41.1415  -73.3579     -1.08        65
# 26       26           Hirara      JP  24.8000  125.2833     17.10        67
# 27       27           Albany      US  42.6001  -73.9662     -5.87        62
# 28       28    Mar Del Plata      AR -38.0023  -57.5575     18.53        95
# 29       29          Sandovo      RU  58.4602   36.4128    -12.13        97
# 30       30         Necochea      AR -38.5473  -58.7368     17.39        77
# 31       31        Hithadhoo      MV  -0.6000   73.0833     28.24        73
# 32       32        Mahebourg      MU -20.4081   57.7000     26.96        89
# 33       33         Udachnyy      RU  66.4167  112.4000    -35.09       100
# 34       34            Buala      SB  -8.1450  159.5921     27.27        83
# 35       35          Biltine      TD  14.5333   20.9167     22.19        14
# 36       36        Carnarvon      AU -24.8667  113.6333     27.19        83
# 37       37            Kieta      PG  -6.2167  155.6333     26.96        83
# 38       38           Barrow      US  71.2906 -156.7887    -24.84        70
# 39       39       Kaitangata      NZ -46.2817  169.8464      7.53        88
# 40       40           Hobart      AU -42.8794  147.3294     14.07        79
# 41       41           Tahara      JP  34.6667  137.2667      3.12        64
# 42       42           Avarua      CK -21.2078 -159.7750     27.18        78
# 43       43           Atuona      PF  -9.8000 -139.0333     26.14        75
# 44       44         Bayangol      RU  50.6977  103.4656    -22.58        97
# 45       45           Dalvik      IS  65.9702  -18.5286     -9.89        97
# 46       46           Manaus      BR  -3.1019  -60.0250     29.43        74
# 47       47             Lasa      IT  46.6166   10.7002      3.85        68
# 48       48           Nagato      JP  34.3833  131.2000      4.10        60
# 49       49           Dikson      RU  73.5069   80.5464    -27.65       100
#
#     Cloudiness  Wind Speed          Current Description
# 0           75        9.26  light intensity shower rain
# 1           99        3.13                   light rain
# 2            2        4.81                    clear sky
# 3            0        6.69                    clear sky
# 4            0        4.12                    clear sky
# 5           40        6.69             scattered clouds
# 6           27        0.73             scattered clouds
# 7            0        2.54                    clear sky
# 8            0        2.87                    clear sky
# 9           10        8.25                    clear sky
# 10          40        3.09             scattered clouds
# 11          40        4.47             scattered clouds
# 12          73        1.52                   light rain
# 13          36        3.88             scattered clouds
# 14          97        2.32              overcast clouds
# 15           0        9.26                 thunderstorm
# 16           8        1.34                    clear sky
# 17          20        5.14                   few clouds
# 18         100        6.17                moderate rain
# 19          75        0.89                broken clouds
# 20          75       13.89                broken clouds
# 21          21        3.32                   few clouds
# 22          25        8.69             scattered clouds
# 23          40        1.54             scattered clouds
# 24          95        3.73              overcast clouds
# 25          20        2.24                   few clouds
# 26         100        8.89              overcast clouds
# 27          25        1.79             scattered clouds
# 28         100        0.45                moderate rain
# 29          96        3.74              overcast clouds
# 30         100       10.51              overcast clouds
# 31          92        6.46              overcast clouds
# 32          75        9.26  light intensity shower rain
# 33          80        1.48                broken clouds
# 34          96        3.08              overcast clouds
# 35          53        7.73                broken clouds
# 36          27        4.63             scattered clouds
# 37         100        3.16              overcast clouds
# 38          75        5.66                broken clouds
# 39          43        2.84             scattered clouds
# 40          40        2.06             scattered clouds
# 41          87        9.96                   light snow
# 42          20        5.66                   few clouds
# 43          16       10.36                   few clouds
# 44          93        1.72              overcast clouds
# 45         100       10.35                         snow
# 46          40        2.06             scattered clouds
# 47           9        2.19                    clear sky
# 48          78       10.63                broken clouds
# 49          98        1.63              overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 25
# What is the maximum temperature you would like for your trip? 35

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Souillac      MU -20.5167   57.5167     27.02        89
# 3          3     Cape Town      ZA -33.9258   18.4232     25.64        65
# 4          4  Saint-Pierre      RE -21.3393   55.4781     27.97        69
# 9          9        Faanui      PF -16.4833 -151.7500     27.39        71
# 11        11    Vila Velha      BR -20.3297  -40.2925     29.12        79
# ..       ...           ...     ...      ...       ...       ...       ...
# 674      674       Mersing      MY   2.4312  103.8405     27.10        83
# 676      676       Kismayo      SO  -0.3582   42.5454     25.93        80
# 677      677    Banda Aceh      ID   5.5577   95.3222     26.29        78
# 679      679     Namatanai      PG  -3.6667  152.4333     26.81        78
# 683      683     Kununurra      AU -15.7667  128.7333     26.14        94
#
#      Cloudiness  Wind Speed          Current Description
# 0            75        9.26  light intensity shower rain
# 3             0        6.69                    clear sky
# 4             0        4.12                    clear sky
# 9            10        8.25                    clear sky
# 11           40        4.47             scattered clouds
# ..          ...         ...                          ...
# 674         100        6.17              overcast clouds
# 676          95        5.35              overcast clouds
# 677         100        2.20              overcast clouds
# 679          75        4.25                broken clouds
# 683         100        0.00              overcast clouds
#
# [174 rows x 10 columns]

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                174
# City                   174
# Country                174
# Lat                    174
# Lng                    174
# Max Temp               174
# Humidity               174
# Cloudiness             174
# Wind Speed             174
# Current Description    174
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Souillac      MU -20.5167   57.5167     27.02        89
# 3          3     Cape Town      ZA -33.9258   18.4232     25.64        65
# 4          4  Saint-Pierre      RE -21.3393   55.4781     27.97        69
# 9          9        Faanui      PF -16.4833 -151.7500     27.39        71
# 11        11    Vila Velha      BR -20.3297  -40.2925     29.12        79
# ..       ...           ...     ...      ...       ...       ...       ...
# 674      674       Mersing      MY   2.4312  103.8405     27.10        83
# 676      676       Kismayo      SO  -0.3582   42.5454     25.93        80
# 677      677    Banda Aceh      ID   5.5577   95.3222     26.29        78
# 679      679     Namatanai      PG  -3.6667  152.4333     26.81        78
# 683      683     Kununurra      AU -15.7667  128.7333     26.14        94
#
#      Cloudiness  Wind Speed          Current Description
# 0            75        9.26  light intensity shower rain
# 3             0        6.69                    clear sky
# 4             0        4.12                    clear sky
# 9            10        8.25                    clear sky
# 11           40        4.47             scattered clouds
# ..          ...         ...                          ...
# 674         100        6.17              overcast clouds
# 676          95        5.35              overcast clouds
# 677         100        2.20              overcast clouds
# 679          75        4.25                broken clouds
# 683         100        0.00              overcast clouds
#
# [174 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""

hotel_df.head(10)
# Out:
#                City Country  Max Temp          Current Description      Lat  \
# 0          Souillac      MU     27.02  light intensity shower rain -20.5167
# 3         Cape Town      ZA     25.64                    clear sky -33.9258
# 4      Saint-Pierre      RE     27.97                    clear sky -21.3393
# 9            Faanui      PF     27.39                    clear sky -16.4833
# 11       Vila Velha      BR     29.12             scattered clouds -20.3297
# 12            Balao      EC     28.10                   light rain  -2.9167
# 13         Lorengau      PG     27.21             scattered clouds  -2.0226
# 15  Arraial Do Cabo      BR     31.13                 thunderstorm -22.9661
# 22       Butaritari      KI     28.06             scattered clouds   3.0707
# 23     Port Hedland      AU     29.18             scattered clouds -20.3167
#
#          Lng Hotel Name
# 0    57.5167
# 3    18.4232
# 4    55.4781
# 9  -151.7500
# 11  -40.2925
# 12  -79.8167
# 13  147.2712
# 15  -42.0278
# 22  172.7902
# 23  118.5667

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
hotels = []
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for i in range(len(hotel_df)):
    
    # 6c. Get latitude and longitude from DataFrame
    lat = hotel_df.iloc[i]['Lat']
    lng = hotel_df.iloc[i]['Lng']
    
    params = {"location":f'{lat},{lng}',
              "radius": 5000, 
              "types": "lodging", 
             "key": g_key}
        
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    

    # 6e. Make request and retrieve the JSON data from the search. 
    response = requests.get(url,params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotels.append(response['results'][0]['name'])
    except:
        hotels.append("")
hotel_df["Hotel Name"] = hotels

hotel_df
# Out:
#              City Country  Max Temp          Current Description      Lat  \
# 0        Souillac      MU     27.02  light intensity shower rain -20.5167
# 3       Cape Town      ZA     25.64                    clear sky -33.9258
# 4    Saint-Pierre      RE     27.97                    clear sky -21.3393
# 9          Faanui      PF     27.39                    clear sky -16.4833
# 11     Vila Velha      BR     29.12             scattered clouds -20.3297
# ..            ...     ...       ...                          ...      ...
# 674       Mersing      MY     27.10              overcast clouds   2.4312
# 676       Kismayo      SO     25.93              overcast clouds  -0.3582
# 677    Banda Aceh      ID     26.29              overcast clouds   5.5577
# 679     Namatanai      PG     26.81                broken clouds  -3.6667
# 683     Kununurra      AU     26.14              overcast clouds -15.7667
#
#           Lng                          Hotel Name
# 0     57.5167         Shanti Maurice Resort & Spa
# 3     18.4232   Southern Sun Waterfront Cape Town
# 4     55.4781                       Lindsey Hôtel
# 9   -151.7500  Bora-Bora Pearl Beach Resort & Spa
# 11   -40.2925           Quality Suites Vila Velha
# ..        ...                                 ...
# 674  103.8405                       Timotel Hotel
# 676   42.5454                          Agan-Hotel
# 677   95.3222         Sulthan Hotel International
# 679  152.4333               Seagulls Inn Namatani
# 683  128.7333                     Hotel Kununurra
#
# [174 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#              City Country  Max Temp          Current Description      Lat  \
# 0        Souillac      MU     27.02  light intensity shower rain -20.5167
# 3       Cape Town      ZA     25.64                    clear sky -33.9258
# 4    Saint-Pierre      RE     27.97                    clear sky -21.3393
# 9          Faanui      PF     27.39                    clear sky -16.4833
# 11     Vila Velha      BR     29.12             scattered clouds -20.3297
# ..            ...     ...       ...                          ...      ...
# 674       Mersing      MY     27.10              overcast clouds   2.4312
# 676       Kismayo      SO     25.93              overcast clouds  -0.3582
# 677    Banda Aceh      ID     26.29              overcast clouds   5.5577
# 679     Namatanai      PG     26.81                broken clouds  -3.6667
# 683     Kununurra      AU     26.14              overcast clouds -15.7667
#
#           Lng                          Hotel Name
# 0     57.5167         Shanti Maurice Resort & Spa
# 3     18.4232   Southern Sun Waterfront Cape Town
# 4     55.4781                       Lindsey Hôtel
# 9   -151.7500  Bora-Bora Pearl Beach Resort & Spa
# 11   -40.2925           Quality Suites Vila Velha
# ..        ...                                 ...
# 674  103.8405                       Timotel Hotel
# 676   42.5454                          Agan-Hotel
# 677   95.3222         Sulthan Hotel International
# 679  152.4333               Seagulls Inn Namatani
# 683  128.7333                     Hotel Kununurra
#
# [174 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file="WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
